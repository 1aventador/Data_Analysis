# %%
import numpy as np
from scipy.stats import pearsonr
import pandas as pd
import scipy.stats as ss
import matplotlib.pyplot as plt

# %%
# Рассчитываем коэффициент корреляции Пирсона
x = np.array([4, 5, 2, 3, 1])
y = np.array([2, 1, 4, 3, 5])

w = ss.pearsonr(x, y)
w
# Out:
# PearsonRResult(statistic=-1.0, pvalue=0.0)

# %%
plt.scatter(X, Y, color='blue')
plt.plot(np.sort(X), np.sort(Y)[::-1], color='red', linestyle='--')  


plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot of X vs. Y with Perfect Negative Correlation')


plt.grid(True)
plt.show()
